# %%
import sys
from PyQt5.QtWidgets import QMainWindow, QApplication, QWidget, QPushButton, QAction
from PyQt5.QtGui import QIcon
from PyQt5.QtCore import pyqtSlot
import pandas as pd
import numpy as np

# %%
#%% DATA EXTRACTION (into pandas dataframe, maybe drag and drop into Qtdesign)

#load dataframe from csv
df = pd.read_csv("egr_edward_practice_1_062922.rf_1.iox.csv", header = 113, sep = ',')


#load dataframe from xlsx
#df_xlsx = pd.read_excel("egr_edward_practice_1_062922.rf_1.iox.xlsx")

#print dataframe
print(df.head(200))
# Out:
#      114 Unnamed: 1       Unnamed: 2 Unnamed: 3   Unnamed: 4      Unnamed: 5  \
# 0    115        NaN              NaN        NaN          NaN             NaN
# 1    116   cpu-date         cpu-time  site-time  period-time             NaN
# 2    117  29-Jun-22  10:51:21 AM.340    00:00.0          NaN    stream-start
# 3    118  29-Jun-22  10:51:23 AM.340    00:02.0          NaN  Ventilation on
# 4    119  29-Jun-22  10:51:23 AM.500    00:02.2          NaN    period-start
# ..   ...        ...              ...        ...          ...             ...
# 195  310  29-Jun-22  10:52:30 AM.167    01:08.8      01:06.7             NaN
# 196  311  29-Jun-22  10:52:30 AM.612    01:09.3      01:07.1             NaN
# 197  312  29-Jun-22  10:52:30 AM.954    01:09.6      01:07.5             NaN
# 198  313  29-Jun-22  10:52:31 AM.370    01:10.0      01:07.9             NaN
# 199  314  29-Jun-22  10:52:32 AM.553    01:11.2      01:09.1             NaN
#
# ...

# %% [markdown]
# # Reading Data in Pandas

# %%
## Read Headers
df.columns

## Read each columns
# Out:
# Index(['114', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'parameter', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Ti', 'Te', 'PIF', 'PEF', 'TV', 'EV',
#        'RT', 'MV', 'P', 'f', 'EIP', 'EEP', 'Penh', 'EF50', 'RH', 'Tbox',
#        'Tbody', 'Patm', 'VCF', 'AV', 'Sr', 'n'],
#       dtype='object')

# %%
## Read each row

#for index,row in df.iterrows():
#    print(index, row['Name'])

## Read a specific location
df.iloc[5:100]
# Out:
#     114 Unnamed: 1       Unnamed: 2 Unnamed: 3   Unnamed: 4      Unnamed: 5  \
# 1   116   cpu-date         cpu-time  site-time  period-time             NaN
# 2   117  29-Jun-22  10:51:21 AM.340    00:00.0          NaN    stream-start
# 3   118  29-Jun-22  10:51:23 AM.340    00:02.0          NaN  Ventilation on
# 4   119  29-Jun-22  10:51:23 AM.500    00:02.2          NaN    period-start
# 5   120  29-Jun-22  10:51:23 AM.565    00:02.2      00:00.1             NaN
# ..  ...        ...              ...        ...          ...             ...
# 95  210  29-Jun-22  10:51:52 AM.886    00:31.5      00:29.4             NaN
# 96  211  29-Jun-22  10:51:53 AM.451    00:32.1      00:30.0             NaN
# 97  212  29-Jun-22  10:51:53 AM.847    00:32.5      00:30.3             NaN
# 98  213  29-Jun-22  10:51:54 AM.142    00:32.8      00:30.6             NaN
# 99  214  29-Jun-22  10:51:54 AM.293    00:33.0      00:30.8             NaN
#
# ...

# %%
#1:1 mapping to new names
new_names = {
  'Unnamed: 1': 'CPU Date',
  'Unnamed: 2': 'CPU Time',
  'Unnamed: 3': 'Site Time',
  'Unnamed: 4': 'Period Time',
  'Unnamed: 5': 'Instruction',
  'parameter': 'Parameter',
  'Unnamed: 7': 'Smoothing info?',
  'Unnamed: 9': 'STO ID',
  'Unnamed: 10': 'First Beat ID',
  'Unnamed: 11': 'Last Beat ID'   
}

#do rename
df.rename(
  columns = new_names, 
  inplace = True
)

df.iloc[5:100]
# Out:
#     114   CPU Date         CPU Time Site Time Period Time Instruction  \
# 5   120  29-Jun-22  10:51:23 AM.565   00:02.2     00:00.1         NaN
# 6   121  29-Jun-22  10:51:23 AM.710   00:02.4     00:00.2         NaN
# 7   122  29-Jun-22  10:51:23 AM.840   00:02.5     00:00.3         NaN
# 8   123  29-Jun-22  10:51:23 AM.976   00:02.6     00:00.5         NaN
# 9   124  29-Jun-22  10:51:24 AM.395   00:03.1     00:00.9         NaN
# ..  ...        ...              ...       ...         ...         ...
# 95  210  29-Jun-22  10:51:52 AM.886   00:31.5     00:29.4         NaN
# 96  211  29-Jun-22  10:51:53 AM.451   00:32.1     00:30.0         NaN
# 97  212  29-Jun-22  10:51:53 AM.847   00:32.5     00:30.3         NaN
# 98  213  29-Jun-22  10:51:54 AM.142   00:32.8     00:30.6         NaN
# 99  214  29-Jun-22  10:51:54 AM.293   00:33.0     00:30.8         NaN
#
#    Parameter Smoothing info?  Unnamed: 8 STO ID  ...  Penh   EF50    RH  \
# ...
